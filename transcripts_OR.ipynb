# %%
import os
import csv
from collections import defaultdict
from Bio import SeqIO

folder_path = 'C:/Users/seq'
filename = 'cds_from_genomic_thuringiensis.fna'
file_path = os.path.join(folder_path, filename)
transcripts = []

for seq_record in SeqIO.parse(file_path, "fasta"):
    seq = seq_record.seq
    codons = [seq[i:i+3] for i in range(0, len(seq) - 1, 3)]

    transcripts.append(set(codons))
all_codons = set()

for transcript in transcripts:
    for codon in transcript:
        all_codons.add(codon)

# print(all_codons)
# res(c1,c2) = (p(c1 & c2) / p(c1) * p(c2))

p_single = defaultdict(int)
p_double = defaultdict(lambda: defaultdict(int))

for codon in all_codons:
    counts_of_occurs = 0
    for transcript in transcripts:
        if codon in transcript:
            counts_of_occurs += 1

    p_single[codon] = counts_of_occurs / len(transcripts)

# print(p_single)

for codon1 in all_codons:
    for codon2 in all_codons:
        counts_of_occurs = 0
        for transcript in transcripts:
            if (codon1 in transcript) and (codon2 in transcript):
                counts_of_occurs += 1
        p_double[codon1][codon2] = counts_of_occurs / len(transcripts)

# print(p_double)
res = defaultdict(lambda: defaultdict(int))

for codon1 in all_codons:
    for codon2 in all_codons:
        res[codon1][codon2] = p_double[codon1][codon2] / (p_single[codon1] * p_single[codon2])

print(res)
csv_file_path = file_path + '_probabilities.csv'
all_sorted_codons = sorted(all_codons)

with open(csv_file_path, 'w') as f:
    w = csv.writer(f)
    w.writerow(['codon1', 'codon2', 'probability'])
    written_codons = set()

    for codon1 in all_sorted_codons:
        for codon2 in all_sorted_codons:
            if (codon2 in written_codons) or (codon1 == codon2):
                continue
            w.writerow([codon1, codon2, res[codon1][codon2]])
        written_codons.add(codon1)
# Out:
# defaultdict(<function <lambda> at 0x0000024C40507920>, {Seq('GAG'): defaultdict(<class 'int'>, {Seq('GAG'): 1.1128342245989307, Seq('CCC'): 1.0379622335671328, Seq('GGT'): 1.016091523303449, Seq('TCA'): 1.0205056707997884, Seq('TGA'): 1.0122702579271303, Seq('TTG'): 1.031054056311424, Seq('AAA'): 1.0039231231604695, Seq('GCC'): 1.039657780549621, Seq('GCG'): 1.0416512867440832, Seq('CTC'): 1.0392891056167584, Seq('GTG'): 1.027298560552895, Seq('GCT'): 1.0136105915333695, Seq('GGA'): 1.0096728367772378, Seq('CTT'): 1.0204299511175592, Seq('ATT'): 1.0045212580770944, Seq('CAC'): 1.0593506235853227, Seq('ATA'): 1.0121989344944868, Seq('CCG'): 1.0539627593740055, Seq('ATG'): 1.0045388842718093, Seq('CGG'): 1.0639884475650079, Seq('CCA'): 1.031453490487104, Seq('CAG'): 1.04785682814762, Seq('AGA'): 1.0331054355509748, Seq('TGG'): 1.0252457810720883, Seq('AAC'): 1.0299908479403763, Seq('TAT'): 1.0141546214342578, Seq('ACC'): 1.0461708325502725, Seq('CCT'): 1.032109286103003, Seq('CGA'): 1.0560424805520343, Seq('ACG'): 1.0402146294195551, Seq('CGT'): 1.0446153534024707, Seq('TGT'): 1.0299523587251012, Seq('GTC'): 1.0370304080193362, Seq('GGG'): 1.0382891941113979, Seq('CAA'): 1.01592802282597, Seq('TTA'): 1.0055446606938787, Seq('AAT'): 1.0097564563220784, Seq('ATC'): 1.0226451452745684, Seq('GAT'): 1.0171304812834228, Seq('TTC'): 1.0196990959074284, Seq('GAA'): 1.010214453601967, Seq('TCC'): 1.0385135019614176, Seq('GCA'): 1.0166822829898663, Seq('GGC'): 1.0296035504455525, Seq('CTA'): 1.026446859396985, Seq('TCT'): 1.0253427150068768, Seq('CTG'): 1.0570824770250882, Seq('GTA'): 1.0116674769081186, Seq('AGC'): 1.0351004732808389, Seq('TAG'): 1.0131774283661903, Seq('TTT'): 1.006638572908193, Seq('TGC'): 1.0381838612428937, Seq('ACT'): 1.0216841769360383, Seq('GAC'): 1.0464360011741733, Seq('AGG'): 1.061265971979276, Seq('CGC'): 1.055198727269507, Seq('TAC'): 1.0332801824342743, Seq('AGT'): 1.0197415574486997, Seq('TCG'): 1.050889653232444, Seq('ACA'): 1.0139366376039873, Seq('TAA'): 0.9939495473314486, Seq('AAG'): 1.0245509249439007, Seq('CAT'): 1.030645581718655, Seq('GTT'): 1.0132252051720552}), Seq('CCC'): defaultdict(<class 'int'>, {Seq('GAG'): 1.0379622335671328, Seq('CCC'): 4.421388101983003, Seq('GGT'): 1.0591453057788578, Seq('TCA'): 1.0859123525200012, Seq('TGA'): 1.1240073029867417, Seq('TTG'): 1.115528435822704, Seq('AAA'): 1.001095949447702, Seq('GCC'): 1.3672840997757612, Seq('GCG'): 1.0830673034680702, Seq('CTC'): 1.409354351600056, Seq('GTG'): 1.0740003955921944, Seq('GCT'): 1.0626913429259586, Seq('GGA'): 1.0468488951253427, Seq('CTT'): 1.0665768005499443, Seq('ATT'): 1.0117955194316572, Seq('CAC'): 1.2401757520458225, Seq('ATA'): 1.1123980196546355, Seq('CCG'): 1.126192413926604, Seq('ATG'): 1.0073138067984058, Seq('CGG'): 1.4597330947386629, Seq('CCA'): 1.1036760549356666, Seq('CAG'): 1.1469282775510952, Seq('AGA'): 1.1162778033462637, Seq('TGG'): 1.1319046590826412, Seq('AAC'): 1.0994088603549448, Seq('TAT'): 1.0397533566379153, Seq('ACC'): 1.5803284150458417, Seq('CCT'): 1.166703546675498, Seq('CGA'): 1.2195765598988584, Seq('ACG'): 1.0896855529732605, Seq('CGT'): 1.10004983527772, Seq('TGT'): 1.1242239196693022, Seq('GTC'): 1.2647094775710666, Seq('GGG'): 1.1127283078029009, Seq('CAA'): 1.0267115995208853, Seq('TTA'): 1.0119424970770232, Seq('AAT'): 1.0278719978595117, Seq('ATC'): 1.0972226179582578, Seq('GAT'): 1.0257620396600566, Seq('TTC'): 1.1144249635228962, Seq('GAA'): 1.012437980591179, Seq('TCC'): 1.424582241029692, Seq('GCA'): 1.037237862823207, Seq('GGC'): 1.146433364582662, Seq('CTA'): 1.1236724589201974, Seq('TCT'): 1.1010428742746472, Seq('CTG'): 1.237230882855494, Seq('GTA'): 1.0270269822453832, Seq('AGC'): 1.1517270971452207, Seq('TAG'): 1.064652657392922, Seq('TTT'): 1.0246741503182553, Seq('TGC'): 1.2708298987041327, Seq('ACT'): 1.0906426750995701, Seq('GAC'): 1.1310081519283925, Seq('AGG'): 1.275797735034815, Seq('CGC'): 1.1635932553848674, Seq('TAC'): 1.1204636652973918, Seq('AGT'): 1.07965069 ...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 57
#      54 csv_file_path = file_path + '_probabilities.csv'
#      55 all_sorted_codons = sorted(all_codons)
# ---> 57 with open(csv_file_path, 'w') as f:
#      58     w = csv.writer(f)
#      59     w.writerow(['codon1', 'codon2', 'probability'])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'C:/Users/seq\\cds_from_genomic_thuringiensis.fna_probabilities.csv'

# %%
path = 'C:\\Users\\Kasia\\OneDrive\\'
csv_file_path = path + 'thuringiensis_transcripts_probabilities.csv'
all_sorted_codons = sorted(all_codons)

with open(csv_file_path, 'w', newline='') as f:
    w = csv.writer(f)
    w.writerow(['codon1', 'codon2', 'probability'])

    for codon1 in all_sorted_codons:
        for codon2 in all_sorted_codons:
            if codon2 in res[codon1]:
                w.writerow([codon1, codon2, res[codon1][codon2]])

print("Results saved to", csv_file_path)
# Out:
# Results saved to C:\Users\Kasia\OneDrive\thuringiensis_transcripts_probabilities.csv
